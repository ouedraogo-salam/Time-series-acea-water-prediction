# %% [markdown]
# # <p style="color:#38C77C; text-align:center">📈 ANALYSE DES DONNÉES À SÉRIE TEMPORELLES 📈</p>
# ## <p style="color:#38C77C; text-align:center">AUTEUR : OUEDRAOGO SALAM</p>
# ## <p style="color:#38C77C; text-align:center">DATE : 2023-02-27</p>
# ---------------------------
# ## <p style="text-align:center; background-color:#A43DC2; padding:12px;">PLAN DE TRAVAIL</p>
#
# 1. INTRODUCTION
# 2. PRÉPARATION DES DONNÉES
#     2.1.	COLLECTE DES DONNÉES
#     2.2.	ÉVALUATION DES DONNÉES
#     2.3.	NETTOYAGE DES DONNÉES
#     2.4.	CONCLUSION
# 3. ANALYSE EXPLORATOIRE
#     3.1.	ANALYSE DE LA VARIABLE DÉPENDANTE
#     3.2.	ANALYSE DES VARIABLES INDÉPENDANTES QUANTITATIVES
#     3.3.	ANALYSE DES VARIABLES INDÉPENDANTES QUALITATIVES
# 4. FEATURE INGENERING
# 5. DÉVELOPPEMENT DU MODEL
# 6. CONCLUSION ET LIMITES
# 7. RÉFÉRENCES
#
# ## <p style="text-align:center; background-color:#A43DC2; padding:10px;">INTRODUCTION</p>

# %% [markdown]
# import numpy as np
# import pandas as pd

# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv("garments_worker_productivity.csv")
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
#         smv     wip  over_time  incentive  idle_time  idle_men  \
# 0     26.16  1108.0       7080         98        0.0         0
# 1      3.94     NaN        960          0        0.0         0
# 2     11.41   968.0       3660         50        0.0         0
# 3     11.41   968.0       3660         50        0.0         0
# 4     25.90  1170.0       1920         50        0.0         0
# ...     ...     ...        ...        ...        ...       ...
# 1192   2.90     NaN        960          0        0.0         0
# 1193   3.90     NaN        960          0        0.0         0
# 1194   3.90     NaN        960          0        0.0         0
# 1195   2.90     NaN       1800          0        0.0         0
# 1196   2.90     NaN        720          0        0.0         0
#
#       no_of_style_change  no_of_workers  actual_productivity
# 0                      0           59.0             0.940725
# 1                      0            8.0             0.886500
# 2                      0           30.5             0.800570
# 3                      0           30.5             0.800570
# 4                      0           56.0             0.800382
# ...                  ...            ...                  ...
# 1192                   0            8.0             0.628333
# 1193                   0            8.0             0.625625
# 1194                   0            8.0             0.625625
# 1195                   0           15.0             0.505889
# 1196                   0            6.0             0.394722
#
# [1197 rows x 15 columns]
